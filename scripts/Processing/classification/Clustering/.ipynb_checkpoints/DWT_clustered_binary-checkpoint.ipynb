# %% [markdown]
# ## Train model for Clusters

# %%
model_name = 'Clusters'

# %% [markdown]
# ### Import libraries

# %%
from utilsclust import *

# %% [markdown]
# ### Import data

# %%
filename = '/mnt/d/sharegit/MasterThesis_data/DWTs/pp01_t16.csv'
df = pd.read_csv(filename, header=None)
filename = '/mnt/d/sharegit/MasterThesis_data/DWTs/clustered_dataframe.csv'
df_scores = pd.read_csv(filename)
clusters = list(df_scores['Cluster'])

# %%
df.replace([np.inf, -np.inf], np.nan, inplace=True)

channels = ['Fp1', 'Fp2', 'F3', 'F4', 'C3', 'C4', 'P3', 'P4', 'O1', 'O2', 'F7', 'F8', 'T7', 'T8', 'P7', 'P8', 'Fz', 'Cz', 'Pz', 'AFz', 'CPz', 'POz']
patterns = ['_d1', '_d2', '_d3', '_d4', '_d5', '_a1']
column_names = ['channels', 'ID', 'Class', 'Epoch'] + [f'{ch}{pt}' for ch in channels for pt in patterns ]

if len(column_names) != len(df.columns):
    raise ValueError(f"Number of column names ({len(column_names)}) does not match number of columns in DataFrame ({len(df.columns)})")

df.columns = column_names
df.head()
# Out:
#    channels  ID  Class  Epoch    Fp1_d1    Fp1_d2    Fp1_d3    Fp1_d4  \
# 0         5   1      1      1  0.575075  0.136032  0.123487  0.093560
# 1         5   1      1      2  0.509184  0.262941  0.106593  0.072962
# 2         5   1      1      3  0.490340  0.191802  0.204283  0.070682
# 3         5   1      1      4  0.436777  0.235945  0.218578  0.060795
# 4         5   1      1      5  0.398432  0.307515  0.197477  0.053886
#
#      Fp1_d5    Fp1_a1  ...    CPz_d3    CPz_d4    CPz_d5    CPz_a1    POz_d1  \
# 0  0.057901  0.013945  ...  0.140594  0.042888  0.025799  0.006609  0.336483
# 1  0.037227  0.011093  ...  0.163608  0.041396  0.009745  0.001428  0.244889
# 2  0.033491  0.009402  ...  0.218914  0.044268  0.010597  0.001778  0.273779
# 3  0.038248  0.009657  ...  0.273868  0.036003  0.010619  0.001746  0.369812
# 4  0.033593  0.009097  ...  0.303220  0.038299  0.007286  0.001249  0.214284
#
#      POz_d2    POz_d3    POz_d4    POz_d5    POz_a1
# 0  0.220715  0.231677  0.101612  0.089528  0.019985
# 1  0.384025  0.221724  0.070184  0.060243  0.018934
# 2  0.215197  0.395480  0.070791  0.033080  0.011673
# 3  0.265958  0.274095  0.053359  0.028603  0.008174
# 4  0.327662  0.322558  0.071483  0.049477  0.014537
#
# [5 rows x 136 columns]

# %% [markdown]
# ### Load data into data_array

# %%
# Example usage
final_df, classes = create_all_intensity_observator(df,clusters)
# Out:
# ID01: Repetition factor 03 - Max is: 16 - Min is: 06
# ID02: Repetition factor 02 - Max is: 20 - Min is: 17
# ID03: Repetition factor 02 - Max is: 20 - Min is: 17
# ID04: Repetition factor 02 - Max is: 20 - Min is: 17
# ID05: Repetition factor 02 - Max is: 20 - Min is: 15
# ID06: Repetition factor 02 - Max is: 20 - Min is: 17
# ID07: Repetition factor 02 - Max is: 20 - Min is: 17
# ID08: Repetition factor 02 - Max is: 20 - Min is: 17
# ID09: Repetition factor 02 - Max is: 20 - Min is: 17
# ID10: Repetition factor 02 - Max is: 20 - Min is: 17
# ID11: Repetition factor 02 - Max is: 20 - Min is: 17
# ID12: Repetition factor 02 - Max is: 20 - Min is: 17
# ID13: Repetition factor 02 - Max is: 19 - Min is: 14
# ID14: Repetition factor 02 - Max is: 20 - Min is: 17
# ID15: Repetition factor 02 - Max is: 20 - Min is: 17
# ID16: Repetition factor 02 - Max is: 20 - Min is: 17
# ID17: Repetition factor 02 - Max is: 20 - Min is: 17
# ID18: Repetition factor 02 - Max is: 20 - Min is: 13
# ID19: Repetition factor 02 - Max is: 20 - Min is: 17
# ID20: Repetition factor 02 - Max is: 20 - Min is: 17
# ID21: Repetition factor 02 - Max is: 20 - Min is: 17
# ID22: Repetition factor 02 - Max is: 20 - Min is: 12
# ID23: Repetition factor 02 - Max is: 20 - Min is: 15
# ID24: Repetition factor 02 - Max is: 20 - Min is: 17
# ID25: Repetition factor 02 - Max is: 20 - Min is: 17
# ID26: Repetition factor 02 - Max is: 20 - Min is: 17
# ID27: Repetition factor 02 - Max is: 20 - Min is: 17
# ID28: Repetition factor 02 - Max is: 20 - Min is: 17
# ID29: Repetition factor 02 - Max is: 20 - Min is: 17
# ID30: Repetition factor 02 - Max is: 20 - Min is: 16
# ID31: Repetition factor 02 - Max is: 20 - Min is: 17
# ID32: Repetition factor 02 - Max is: 20 - Min is: 17
# ID33: Repetition factor 02 - Max is: 20 - Min is: 17
# ID34: Repetition factor 02 - Max is: 20 - Min is: 17

# %%
final_df
# Out:
#      Fp1__d1_A1  Fp1__d2_A1  Fp1__d3_A1  Fp1__d4_A1  Fp1__d5_A1  Fp1__a1_A1  \
# 0      0.575075    0.136032    0.123487    0.093560    0.057901    0.013945
# 1      0.509184    0.262941    0.106593    0.072962    0.037227    0.011093
# 2      0.490340    0.191802    0.204283    0.070682    0.033491    0.009402
# 3      0.436777    0.235945    0.218578    0.060795    0.038248    0.009657
# 4      0.398432    0.307515    0.197477    0.053886    0.033593    0.009097
# ..          ...         ...         ...         ...         ...         ...
# 670    0.520923    0.146249    0.227325    0.077945    0.023838    0.003721
# 671    0.440654    0.148458    0.309111    0.078313    0.019596    0.003868
# 672    0.301289    0.144256    0.421904    0.102509    0.026651    0.003391
# 673    0.405805    0.160670    0.293036    0.117079    0.020803    0.002607
# 674    0.482923    0.179566    0.229719    0.086492    0.017628    0.003671
#
#      Fp1__d1_A2  Fp1__d2_A2  Fp1__d3_A2  Fp1__d4_A2  ...  POz__d3_C3  \
# 0      0.547423    0.179707    0.128436    0.079774  ...    0.120006
# 1      0.454395    0.294668    0.132037    0.068668  ...    0.055985
# 2      0.449821    0.230215    0.206960    0.072723  ...    0.108032
# 3      0.404348    0.271724    0.228696    0.058293  ...    0.092514
# 4      0.347098    0.329096    0.221465    0.060126  ...    0.085023
# ..          ...         ...         ...         ...  ...         ...
# 670    0.511574    0.197145    0.186010    0.082555  ...    0.221002
# 671    0.348667    0.201904    0.304249    0.123013  ...    0.199921
# 672    0.348306    0.121300    0.403601    0.092343  ...    0.202985
# 673    0.401348    0.154556    0.297756    0.113953  ...    0.193004
# 674    0.463314    0.221811    0.206030    0.086753  ...    0.258257
#
#      POz__d4_C3  POz__d5_C3  POz__a1_C3  POz__d1_C4  POz__d2_C4  POz__d3_C4  \
# 0      0.058866    0.018769    0.004650    0.310979    0.280219    0.148740
# 1      0.024101    0.008343    0.001890    0.374326    0.261388    0.189394
# 2      0.034976    0.009704    0.002487    0.310311    0.371701    0.153067
# 3      0.037553    0.011085    0.002544    0.415283    0.204239    0.225839
# 4      0.024561    0.011938    0.003414    0.363550    0.392284    0.128789
# ..          ...         ...         ...         ...         ...         ...
# 670    0.097901    0.021570    0.002329    0.465205    0.157267    0.255658
# 671    0.169995    0.028542    0.004070    0.304721    0.153519    0.279493
# 672    0.164066    0.021850    0.002545    0.430492    0.186828    0.221463
# 673    0.116954    0.023412    0.002485    0.412937    0.182140    0.255691
# 674    0.209958    0.026477    0.002647    0.271073    0.191564    0.317466
#
#      POz__d4_C4  POz__d5_C4  POz__a1_C4
# 0      0.145800    0.084847    0.029415
# 1      0.089160    0.064557    0.021176
# 2      0.090099    0.057843    0.016979
# 3      0.088631    0.047929    0.018078
# 4      0.063558    0.035549    0.016269
# ..          ...         ...         ...
# 670    0.082686    0.033793    0.005391
# 671    0.200074    0.053543    0.008649
# 672    0.127088    0.029180    0.004949
# 673    0.107749    0.036119    0.005365
# 674    0.187330    0.028846    0.003720
#
# [675 rows x 1584 columns]

# %%
print(len(classes))
data_array = final_df.values

# Split the data into training and test sets
X_train, X_test, y_train, y_test = train_test_split(data_array, classes, test_size=0.2, random_state=42)
# Out:
# 675

# %%
set(y_train)
# Out:
# {0, 1}

# %% [markdown]
# ### Train models

# %%
models,scores = train_all(X_train, y_train)
# Out:
# ------------------------------------------------------------
# Average K-Fold Test Accuracy of KNN: 98.15%
# Std Dev of K-Fold Test Accuracy of KNN: 1.85%
# Average K-Fold Test Precision of KNN: 0.97
# Average K-Fold Test Recall of KNN: 1.00
# Average K-Fold Test F1 Score of KNN: 0.98
# Average K-Fold Test ROC AUC of KNN: 1.00
# ------------------------------------------------------------
# ------------------------------------------------------------
# Average K-Fold Test Accuracy of Random Forest: 99.44%
# Std Dev of K-Fold Test Accuracy of Random Forest: 0.85%
# Average K-Fold Test Precision of Random Forest: 0.99
# Average K-Fold Test Recall of Random Forest: 1.00
# Average K-Fold Test F1 Score of Random Forest: 1.00
# Average K-Fold Test ROC AUC of Random Forest: 1.00
# ------------------------------------------------------------
# ------------------------------------------------------------
# Average K-Fold Test Accuracy of MLP: 99.63%
# Std Dev of K-Fold Test Accuracy of MLP: 0.74%
# Average K-Fold Test Precision of MLP: 0.99
# Average K-Fold Test Recall of MLP: 1.00
# Average K-Fold Test F1 Score of MLP: 1.00
# Average K-Fold Test ROC AUC of MLP: 1.00
# ------------------------------------------------------------

# %%
accs,ensemble_preds = calculate_acc(X_test, y_test, models)
# Out:
# KNN Classification Accuracy: 0.9925925925925926
# Random Forest Classification Accuracy: 0.9925925925925926
# MLP Classification Accuracy: 0.9777777777777777
# Ensemble Classification Accuracy: 1.0

# %%
def get_mutualInfo(X_train, X_test, y_train, number_of_f=100):
    # Calculate mutual information scores
    mutual_info_scores = mutual_info_classif(X_train, y_train)
    if number_of_f > 0:
        # Sort the mutual information scores in descending order and select the top n features
        sorted_indices = np.argsort(mutual_info_scores)[::-1]
        selected_features = sorted_indices[:number_of_f]
    else:
        raise ValueError("Number of features must be greater than 0.")

    # Filter the training and test sets to include only the selected features
    X_train_sf = X_train[:, selected_features]
    X_test_sf = X_test[:, selected_features]

    # Define the channels and patterns
    channels = ['Fp1', 'Fp2', 'F3', 'F4', 'C3', 'C4', 'P3', 'P4', 'O1', 'O2', 'F7', 'F8', 'T7', 'T8', 'P7', 'P8', 'Fz', 'Cz', 'Pz', 'AFz', 'CPz', 'POz']
    patterns = ['d1', 'd2', 'd3', 'd4', 'd5', 'a1']
    mod_intensity = ['A1','A2','A3','A4','V1','V2','V3','V4','C1','C2','C3','C4']
    feature_names = [f'{ch}_{pt}_{mi}' for ch in channels for pt in patterns for mi in mod_intensity]
    
    # Ensure that feature_names has the same length as mutual_info_scores
    if len(feature_names) != len(mutual_info_scores):
        raise ValueError(f"The number of generated feature names ({len(feature_names)}) does not match the number of features ({len(mutual_info_scores)}) in the data.")
    
    # Print the mutual information scores of the top n features
    print(f"Top {number_of_f} most important features:")
    for i in selected_features:
        print(f"{feature_names[i]}: Mutual Information Score: {mutual_info_scores[i]:.5f}")
    
    # Print the number of selected features
    print(f"Number of features selected: {len(selected_features)}")
    
    return X_train_sf, X_test_sf

# %%
X_train_sf, X_test_sf = get_mutualInfo(X_train, X_test, y_train, number_of_f = 80)
# Out:
# Top 80 most important features:
# P3_d4_V1: Mutual Information Score: 0.16573
# Fp1_d1_C1: Mutual Information Score: 0.15562
# P3_d3_V1: Mutual Information Score: 0.14673
# P3_d4_V2: Mutual Information Score: 0.14403
# F4_d3_A2: Mutual Information Score: 0.13747
# F4_d5_C1: Mutual Information Score: 0.13727
# F4_d1_A1: Mutual Information Score: 0.13687
# Fp2_a1_A3: Mutual Information Score: 0.13670
# C4_d4_A3: Mutual Information Score: 0.13337
# Fp2_d4_V3: Mutual Information Score: 0.13330
# P4_d2_V3: Mutual Information Score: 0.13180
# C3_d1_A4: Mutual Information Score: 0.13164
# Fp2_d2_A3: Mutual Information Score: 0.13009
# F4_d5_A3: Mutual Information Score: 0.12940
# C4_d2_C1: Mutual Information Score: 0.12909
# C4_d5_V1: Mutual Information Score: 0.12720
# C3_d3_C4: Mutual Information Score: 0.12699
# C3_d2_A3: Mutual Information Score: 0.12678
# Fp2_d3_V4: Mutual Information Score: 0.12615
# C3_d2_C4: Mutual Information Score: 0.12607
# Fp2_d1_V2: Mutual Information Score: 0.12427
# P4_d2_V4: Mutual Information Score: 0.12404
# Fp2_d5_C4: Mutual Information Score: 0.12392
# F4_d5_C3: Mutual Information Score: 0.12357
# Fp2_d1_A1: Mutual Information Score: 0.12347
# Fp1_d4_C4: Mutual Information Score: 0.12102
# POz_d3_A4: Mutual Information Score: 0.12083
# F3_d4_A4: Mutual Information Score: 0.12063
# C4_d4_C1: Mutual Information Score: 0.12019
# F4_a1_V2: Mutual Information Score: 0.11946
# C4_d3_V4: Mutual Information Score: 0.11943
# Fp1_d2_C4: Mutual Information Score: 0.11928
# C4_d3_C3: Mutual Information Score: 0.11798
# P3_d4_A4: Mutual Information Score: 0.11790
# C3_d2_A1: Mutual Information Score: 0.11681
# Fp2_d3_C3: Mutual Information Score: 0.11642
# F3_d1_A2: Mutual Information Score: 0.11476
# C3_d5_C1: Mutual Information Score: 0.11416
# F4_d3_V1: Mutual Information Score: 0.11374
# C3_d5_C3: Mutual Information Score: 0.11310
# Fp2_d3_V1: Mutual Information Score: 0.11293
# Fp1_d2_V4: Mutual Information Score: 0.11180
# Fp1_d1_A3: Mutual Information Score: 0.11167
# Fp1_d2_V2: Mutual Information Score: 0.11148
# C3_d1_V3: Mutual Information Score: 0.11101
# P3_d5_C1: Mutual Information Score: 0.11056
# P3_a1_V3: Mutual Information Score: 0.11004
# P4_a1_V2: Mutual Information Score: 0.10955
# F3_d1_V1: Mutual Information Score: 0.10923
# C3_d3_V3: Mutual Information Score: 0.10874
# Fp2_d3_A3: Mutual Information Score: 0.10869
# F4_d5_V1: Mutual Information Score: 0.10861
# P3_d5_C3: Mutual Information Score: 0.10809
# F4_d3_C4: Mutual Information Score: 0.10758
# Fp1_d5_C4: Mutual Information Score: 0.10681
# F3_d3_V2: Mutual Information Score: 0.10654
# C4_d3_C4: Mutual Information Score: 0.10604
# C3_d3_C3: Mutual Information Score: 0.10601
# P4_d1_V1: Mutual Information Score: 0.10539
# C4_d4_C2: Mutual Information Score: 0.10486
# Pz_d2_A2: Mutual Information Score: 0.10463
# P3_d1_C4: Mutual Information Score: 0.10454
# C4_d4_V2: Mutual Information Score: 0.10450
# Pz_d2_C4: Mutual Information Score: 0.10435
# F4_d4_V4: Mutual Information Score: 0.10339
# F4_d2_C1: Mutual Information Score: 0.10307
# F3_a1_V2: Mutual Information Score: 0.10207
# F3_d5_V4: Mutual Information Score: 0.10103
# P3_a1_A1: Mutual Information Score: 0.10101
# C4_d5_A4: Mutual Information Score: 0.10036
# F4_a1_A2: Mutual Information Score: 0.10025
# C3_d4_V4: Mutual Information Score: 0.10007
# Fp1_d1_C4: Mutual Information Score: 0.10005
# C4_d4_C3: Mutual Information Score: 0.09984
# T8_d4_C4: Mutual Information Score: 0.09967
# Fp2_d5_C3: Mutual Information Score: 0.09947
# F3_d3_C3: Mutual Information Score: 0.09946
# Fp2_d2_V3: Mutual Information Score: 0.09917
# P4_d1_A1: Mutual Information Score: 0.09916
# C3_d3_V2: Mutual Information Score: 0.09857
# Number of features selected: 80

# %%
models, scores = train_all(X_train_sf, y_train)
# Out:
# ------------------------------------------------------------
# Average K-Fold Test Accuracy of KNN: 79.26%
# Std Dev of K-Fold Test Accuracy of KNN: 5.84%
# Average K-Fold Test Precision of KNN: 0.85
# Average K-Fold Test Recall of KNN: 0.77
# Average K-Fold Test F1 Score of KNN: 0.80
# Average K-Fold Test ROC AUC of KNN: 0.91
# ------------------------------------------------------------
# ------------------------------------------------------------
# Average K-Fold Test Accuracy of Random Forest: 84.81%
# Std Dev of K-Fold Test Accuracy of Random Forest: 2.72%
# Average K-Fold Test Precision of Random Forest: 0.88
# Average K-Fold Test Recall of Random Forest: 0.85
# Average K-Fold Test F1 Score of Random Forest: 0.86
# Average K-Fold Test ROC AUC of Random Forest: 0.93
# ------------------------------------------------------------
# ------------------------------------------------------------
# Average K-Fold Test Accuracy of MLP: 78.89%
# Std Dev of K-Fold Test Accuracy of MLP: 2.37%
# Average K-Fold Test Precision of MLP: 0.82
# Average K-Fold Test Recall of MLP: 0.81
# Average K-Fold Test F1 Score of MLP: 0.81
# Average K-Fold Test ROC AUC of MLP: 0.88
# ------------------------------------------------------------

# %% [markdown]
# accs,ensemble_preds = calculate_acc(X_test_sf, y_test, models)

# %% [markdown]
# ## Mutal info Features vs Accuracy

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import cross_validate, StratifiedKFold
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.feature_selection import mutual_info_classif, RFECV
from mrmr import mrmr_classif
from sklearn.svm import SVC
import pickle

def get_mutualInfo(X_train, y_train, number_of_f=100):
    mutual_info_scores = mutual_info_classif(X_train, y_train)
    sorted_indices = np.argsort(mutual_info_scores)[::-1]
    selected_features = sorted_indices[:number_of_f]
    X_train_sf = X_train[:, selected_features]
    feature_names = [f'Feature {i+1}' for i in selected_features]  
    return X_train_sf, selected_features

def get_mRMR(X_train, y_train, number_of_f=100):
    X = pd.DataFrame(X_train)
    y = pd.Series(y_train)
    selected_features = mrmr_classif(X, y, K=number_of_f)
    X_train_sf = X_train[:, selected_features]
    return X_train_sf, selected_features

def get_svm_rfe(X_train, y_train, number_of_f=100):
    svc = SVC(kernel="linear")
    rfecv = RFECV(estimator=svc, step=1, cv=StratifiedKFold(5), scoring='accuracy')
    rfecv.fit(X_train, y_train)
    selected_features = np.argsort(rfecv.ranking_)[:number_of_f]
    X_train_sf = X_train[:, selected_features]
    return X_train_sf, selected_features

# Could further add the metrics for ensemble model 
def feature_selection_and_model_training(X_train, X_test, y_train, y_test, feature_counts, method='mutual_info', cv=5):
    results = []
    models_all = []
    for count in feature_counts:
        if method == 'mutual_info':
            X_train_sf, selected_features = get_mutualInfo(X_train, y_train, number_of_f=count)
        elif method == 'mrmr':
            X_train_sf, selected_features = get_mRMR(X_train, y_train, number_of_f=count)
        elif method == 'svm_rfe':
            X_train_sf, selected_features = get_svm_rfe(X_train, y_train, number_of_f=count)
        else:
            raise ValueError(f"Unknown feature selection method: {method}")
        
        X_test_sf = X_test[:, selected_features]
        print(f'Computed features {count} using {method}')
        models, scores = train_all(X_train_sf, y_train, cv=cv, echo=False)
        
        model_all = {
            'KNN': models[0],
            'RF': models[1],
            'MLP': models[2],
        }  
        models_all.append(model_all)
        
        for model, score, name in zip(models, scores, ['KNN', 'RF', 'MLP']):                          
            y_pred_sf = model.predict(X_test_sf)
            
            result = {
                'name': name,
                'features': count,
                'test_accuracy': np.mean(score['test_accuracy']) * 100,
                'train_accuracy': np.mean(score['train_accuracy']) * 100,
                'test_precision': np.mean(score['test_precision']),
                'test_recall': np.mean(score['test_recall']),
                'test_f1': np.mean(score['test_f1']),
                'test_roc_auc': np.mean(score['test_roc_auc']),
                'retained_features': selected_features
            }
            results.append(result)

    return results, models_all

def plot_features_vs_accuracy(results, metric = 'test_accuracy'):
    plt.figure(figsize=(5, 5))
    
    models = ['KNN', 'RF', 'MLP']
    for model in models:
        feature_counts = [result['features'] for result in results if result['name'] == model]
        test_accuracies = [result[metric] for result in results if result['name'] == model]
        plt.plot(feature_counts, test_accuracies, label=model)
    
    plt.xlabel('Number of Features')
    plt.ylabel(metric.replace('_', ' ').title())
    plt.title('Mutual Information')
    plt.legend()
    plt.grid(True)
    plt.show()


def save_to_pkl(filename, obj):
    with open(filename, 'wb') as file:
        pickle.dump(obj, file, protocol=pickle.HIGHEST_PROTOCOL)

def load_from_pkl(filename):
    with open(filename, 'rb') as file:
        return pickle.load(file)

def get_best_model(results):
    best_accuracy = 0
    best_model_info = None
    
    for result in results:
        if result['test_accuracy'] > best_accuracy:
            best_accuracy = result['test_accuracy']
            best_model_info = result
    
    return best_accuracy, best_model_info

# %%
from collections import Counter

# Define the channels, patterns, and mod_intensity
channels = ['Fp1', 'Fp2', 'F3', 'F4', 'C3', 'C4', 'P3', 'P4', 'O1', 'O2', 'F7', 'F8', 'T7', 'T8', 'P7', 'P8', 'Fz', 'Cz', 'Pz', 'AFz', 'CPz', 'POz']
patterns = ['d1', 'd2', 'd3', 'd4', 'd5', 'a1']
mod_intensity = ['A1', 'A2', 'A3', 'A4', 'V1', 'V2', 'V3', 'V4', 'C1', 'C2', 'C3', 'C4']
feature_names = [f'{ch}_{pt}_{mi}' for ch in channels for pt in patterns for mi in mod_intensity]

# Function to find the most repeated components for the best accuracy
def most_repeated_components_best_accuracy(results, feature_names):
    # Identify the best accuracy and the corresponding number of features
    best_accuracy = 0
    best_features_count = 0
    
    for result in results:
        if result['test_accuracy'] > best_accuracy:
            best_accuracy = result['test_accuracy']
            best_features_count = result['features']
    
    # Filter results for the best number of features
    best_results = [result for result in results if result['features'] == best_features_count]
    
    # Initialize counters
    channel_counter = Counter()
    pattern_counter = Counter()
    mod_intensity_counter = Counter()
    
    # Count occurrences of each component
    for result in best_results:
        retained_features = result['retained_features']
        for feature_idx in retained_features:
            feature_name = feature_names[feature_idx]
            channel, pattern, mod_intensity = feature_name.split('_')
            
            channel_counter[channel] += 1
            pattern_counter[pattern] += 1
            mod_intensity_counter[mod_intensity] += 1
    
    # Get the most common components
    most_common_channels = channel_counter.most_common()
    most_common_patterns = pattern_counter.most_common()
    most_common_mod_intensity = mod_intensity_counter.most_common()
    
    return most_common_channels, most_common_patterns, most_common_mod_intensity, best_accuracy, best_features_count

def print_best_most_common(loaded_results, feature_names):
    most_common_channels, most_common_patterns, most_common_mod_intensity, best_accuracy, best_features_count = most_repeated_components_best_accuracy(loaded_results, feature_names)
    best_accuracy, best_model_info = get_best_model(loaded_results)

    # Print the best accuracy and the number of features
    print(f"Best Accuracy: {best_accuracy:.2f}% with {best_features_count} features\n")
    print("Best Model Info:")
    print(f"Model Name: {best_model_info['name']}")
    print(f"Number of Features: {best_model_info['features']}")
    print(f"Train Accuracy: {best_model_info['train_accuracy']:.2f}%")
    print(f"Test Accuracy: {best_model_info['test_accuracy']:.2f}%")
    print(f"Test Precision: {best_model_info['test_precision']:.2f}")
    print(f"Test Recall: {best_model_info['test_recall']:.2f}")
    print(f"Test F1 Score: {best_model_info['test_f1']:.2f}")
    print(f"Test ROC AUC: {best_model_info['test_roc_auc']:.2f}")
    
    # Print the top most common channels, patterns, and modulation intensities
    print("\nTop most common channels:")
    for channel, count in most_common_channels:
        print(f"{channel}: {count} times")
    
    print("\nTop most common patterns:")
    for pattern, count in most_common_patterns:
        print(f"{pattern}: {count} times")
    
    print("\nTop most common modulation intensities:")
    for mod_intensity, count in most_common_mod_intensity:
        print(f"{mod_intensity}: {count} times")

# %% [markdown]
# ## Compute Feature vs. metric curve

# %% [markdown]
# ### SVM-RFE

# %%
feature_counts = np.array([1, 5, 10, 15, 20, 25, 30, 35, 40, 45, 50, 55,60,65,70,75,80])
results, models_all = feature_selection_and_model_training(X_train, X_test, y_train, y_test, feature_counts, method='svm_rfe', cv=5)

filename = '/mnt/d/sharegit/MasterThesis_data/' + model_name + '/svm_rfe_results.pkl'
save_to_pkl(filename, results)
filename = '/mnt/d/sharegit/MasterThesis_data/' + model_name + '/svm_rfe_models_all.pkl'
save_to_pkl(filename, models_all)
# Out:
# Computed features 1 using svm_rfe
# Computed features 5 using svm_rfe
# Computed features 10 using svm_rfe
# Computed features 15 using svm_rfe
# Computed features 20 using svm_rfe
# Computed features 25 using svm_rfe
# Computed features 30 using svm_rfe
# Computed features 35 using svm_rfe
# Computed features 40 using svm_rfe
# Computed features 45 using svm_rfe
# Computed features 50 using svm_rfe
# Computed features 55 using svm_rfe
# Computed features 60 using svm_rfe
# Computed features 65 using svm_rfe
# Computed features 70 using svm_rfe
# Computed features 75 using svm_rfe
# Computed features 80 using svm_rfe

# %% [markdown]
# ### Mutual information

# %%
feature_counts = np.array([1, 5, 10, 15, 20, 25, 30, 35, 40, 45, 50, 55,60,65,70,75,80])
results, models_all = feature_selection_and_model_training(X_train, X_test, y_train, y_test, feature_counts, method='mutual_info', cv=5)

filename = '/mnt/d/sharegit/MasterThesis_data/' + model_name + '/mutual_info_results.pkl'
save_to_pkl(filename, results)
filename = '/mnt/d/sharegit/MasterThesis_data/' + model_name + '/mutual_info_models_all.pkl'
save_to_pkl(filename, models_all)
# Out:
# Computed features 1 using mutual_info
# Computed features 5 using mutual_info
# Computed features 10 using mutual_info
# Computed features 15 using mutual_info
# Computed features 20 using mutual_info
# Computed features 25 using mutual_info
# Computed features 30 using mutual_info
# Computed features 35 using mutual_info
# Computed features 40 using mutual_info
# Computed features 45 using mutual_info
# Computed features 50 using mutual_info
# Computed features 55 using mutual_info
# Computed features 60 using mutual_info
# Computed features 65 using mutual_info
# Computed features 70 using mutual_info
# Computed features 75 using mutual_info
# Computed features 80 using mutual_info

# %% [markdown]
# ### mRMR

# %%
feature_counts = np.array([1, 5, 10, 15, 20, 25, 30, 35, 40, 45, 50, 55, 60, 65, 70, 75, 80])
results, models_all = feature_selection_and_model_training(X_train, X_test, y_train, y_test, feature_counts, method='mrmr', cv=5)

filename = '/mnt/d/sharegit/MasterThesis_data/' + model_name + '/mrmr_results.pkl'
save_to_pkl(filename, results)
filename = '/mnt/d/sharegit/MasterThesis_data/' + model_name + '/mrmr_models_all.pkl'
save_to_pkl(filename, models_all)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[45], line 2
#       1 feature_counts = np.array([1, 5, 10, 15, 20, 25, 30, 35, 40, 45, 50, 55,60,65,70,75,80])
# ----> 2 results, models_all = feature_selection_and_model_training(X_train, X_test, y_train, y_test, feature_counts, method='mrmr', cv=5)
#       4 filename = '/mnt/d/sharegit/MasterThesis_data/' + model_name + '/mrmr_results.pkl'
#       5 save_to_pkl(filename, results)
#
# Cell In[14], line 44, in feature_selection_and_model_training(X_train, X_test, y_train, y_test, feature_counts, method, cv)
#      42     X_train_sf, selected_features = get_mutualInfo(X_train, y_train, number_of_f=count)
#      43 elif method == 'mrmr':
# ---> 44     X_train_sf, selected_features = get_mRMR(X_train, y_train, number_of_f=count)
#      45 elif method == 'svm_rfe':
#      46     X_train_sf, selected_features = get_svm_rfe(X_train, y_train, number_of_f=count)
#
# Cell In[31], line 15, in get_mRMR(X_train, y_train, number_of_f)
#      13 X = pd.DataFrame(X_train)
#      14 y = pd.Series(y_train)
# ---> 15 selected_features = mrmr_classif(X, y, K=number_of_f)
#      16 X_train_sf = X_train[:, selected_features]
#      17 return X_train_sf, selected_features
#
# File ~/anaconda3/envs/tf_test/lib/python3.11/site-packages/mrmr/pandas.py:171, in mrmr_classif(X, y, K, relevance, redundancy, denominator, cat_features, cat_encoding, only_same_domain, return_scores, n_jobs, show_progress)
#     168 relevance_args = {'X': X, 'y': y}
#     169 redundancy_args = {'X': X}
# --> 171 return mrmr_base(K=K, relevance_func=relevance_func, redundancy_func=redundancy_func,
#     172                  relevance_args=relevance_args, redundancy_args=redundancy_args,
#     173                  denominator_func=denominator_func, only_same_domain=only_same_domain,
#     174                  return_scores=return_scores, show_progress=show_progress)
#
# File ~/anaconda3/envs/tf_test/lib/python3.11/site-packages/mrmr/main.py:98, in mrmr_base(K, relevance_func, redundancy_func, relevance_args, redundancy_args, denominator_func, only_same_domain, return_scores, show_progress)
#      44 def mrmr_base(K, relevance_func, redundancy_func,
#      45               relevance_args={}, redundancy_args={},
#      46               denominator_func=np.mean, only_same_domain=False,
#      47               return_scores=False, show_progress=True):
#      48     """General function for mRMR algorithm.
#      49
#      50     Parameters
#    (...)
#      95         List of selected features.
#      96     """
# ---> 98     relevance = relevance_func(**relevance_args)
#      99     features = relevance[relevance.fillna(0) > 0].index.to_list()
#     100     relevance = relevance.loc[features]
#
# File ~/anaconda3/envs/tf_test/lib/python3.11/site-packages/mrmr/pandas.py:45, in f_classif(X, y, n_jobs)
#      44 def f_classif(X, y, n_jobs):
# ---> 45     return parallel_df(_f_classif, X, y, n_jobs=n_jobs)
#
# File ~/anaconda3/envs/tf_test/lib/python3.11/site-packages/mrmr/pandas.py:17, in parallel_df(func, df, series, n_jobs)
#      15 n_jobs = min(cpu_count(), len(df.columns)) if n_jobs == -1 else min(cpu_count(), n_jobs)
#      16 col_chunks = np.array_split(range(len(df.columns)), n_jobs)
# ---> 17 lst = Parallel(n_jobs=n_jobs)(
#      18     delayed(func)(df.iloc[:, col_chunk], series)
#      19     for col_chunk in col_chunks
#      20 )
#      21 return pd.concat(lst)
#
# File ~/anaconda3/envs/tf_test/lib/python3.11/site-packages/joblib/parallel.py:2007, in Parallel.__call__(self, iterable)
#    2001 # The first item from the output is blank, but it makes the interpreter
#    2002 # progress until it enters the Try/Except block of the generator and
#    2003 # reaches the first `yield` statement. This starts the asynchronous
#    2004 # dispatch of the tasks to the workers.
#    2005 next(output)
# -> 2007 return output if self.return_generator else list(output)
#
# File ~/anaconda3/envs/tf_test/lib/python3.11/site-packages/joblib/parallel.py:1650, in Parallel._get_outputs(self, iterator, pre_dispatch)
#    1647     yield
#    1649     with self._backend.retrieval_context():
# -> 1650         yield from self._retrieve()
#    1652 except GeneratorExit:
#    1653     # The generator has been garbage collected before being fully
#    1654     # consumed. This aborts the remaining tasks if possible and warn
#    1655     # the user if necessary.
#    1656     self._exception = True
#
# File ~/anaconda3/envs/tf_test/lib/python3.11/site-packages/joblib/parallel.py:1762, in Parallel._retrieve(self)
#    1757 # If the next job is not ready for retrieval yet, we just wait for
#    1758 # async callbacks to progress.
#    1759 if ((len(self._jobs) == 0) or
#    1760     (self._jobs[0].get_status(
#    1761         timeout=self.timeout) == TASK_PENDING)):
# -> 1762     time.sleep(0.01)
#    1763     continue
#    1765 # We need to be careful: the job list can be filling up as
#    1766 # we empty it and Python list are not thread-safe by
#    1767 # default hence the use of the lock
#
# KeyboardInterrupt:

# %% [markdown]
# ## Plot Curve

# %% [markdown]
# ### SVM-RFE

# %%
filename = '/mnt/d/sharegit/MasterThesis_data/' + model_name + '/svm_rfe_results.pkl'
loaded_results = load_from_pkl(filename)
plot_features_vs_accuracy(loaded_results, metric = 'test_accuracy')

# %% [markdown]
# ### Mutual information

# %%
filename = '/mnt/d/sharegit/MasterThesis_data/' + model_name + '/mutual_info_results.pkl'
loaded_results = load_from_pkl(filename)
plot_features_vs_accuracy(loaded_results, metric = 'test_accuracy')

# %% [markdown]
# ### mRMR

# %%
filename = '/mnt/d/sharegit/MasterThesis_data/' + model_name + '/mrmr_results.pkl'
loaded_results = load_from_pkl(filename)
plot_features_vs_accuracy(loaded_results, metric = 'test_accuracy')

# %% [markdown]
# ### Only RF different feature selection methods

# %%
filenames = ['/mnt/d/sharegit/MasterThesis_data/' + model_name + '/svm_rfe_results.pkl',
             '/mnt/d/sharegit/MasterThesis_data/' + model_name + '/mutual_info_results.pkl',
             '/mnt/d/sharegit/MasterThesis_data/' + model_name + '/mrmr_results.pkl']

feature_methods = ['SVM-RFE', 'Mutual Information', 'mRMR']
model = 'RF'
metric = 'test_accuracy'
max_accuracy = 97.04

plt.figure(figsize=(6, 3))  # Adjust figure size to match the example

for filename, method in zip(filenames, feature_methods):
    loaded_results = load_from_pkl(filename)
    feature_counts = [result['features'] for result in loaded_results if result['name'] == model]
    test_accuracies = [result[metric] for result in loaded_results if result['name'] == model]
    plt.plot(feature_counts, test_accuracies, label=method, linewidth=2.5)

plt.xlabel('Number of Features')
plt.ylabel(metric.replace('_', ' ').title() + ' (%)')
plt.title('Feature Selection Methods Comparison for ' + model)
plt.legend()
plt.ylim((60, 100))
plt.xlim((1, 80))
plt.grid(False)
plt.axhline(y=max_accuracy, color='r', linestyle='--', linewidth=1.4)
plt.text(5, max_accuracy + 1.4, f'Max: {max_accuracy}%', color='r', va='center', ha='left', fontsize=10)
plt.tight_layout()
plt.grid(alpha=.4)

plt.show()

# %% [markdown]
# ## Summary of best Models

# %% [markdown]
# ### SVM-RFE

# %%
filename = '/mnt/d/sharegit/MasterThesis_data/' + model_name + '/svm_rfe_results.pkl'
loaded_results = load_from_pkl(filename)
print(f'SVM-RFE')
print_best_most_common(loaded_results, feature_names)
# Out:
# SVM-RFE
# Best Accuracy: 96.67% with 75 features
#
# Best Model Info:
# Model Name: RF
# Number of Features: 75
# Train Accuracy: 100.00%
# Test Accuracy: 96.67%
# Test Precision: 0.96
# Test Recall: 0.99
# Test F1 Score: 0.97
# Test ROC AUC: 0.99
#
# Top most common channels:
# P7: 54 times
# C4: 36 times
# T8: 33 times
# Fz: 27 times
# O2: 21 times
# Cz: 15 times
# P8: 9 times
# P3: 9 times
# C3: 9 times
# Pz: 6 times
# O1: 3 times
# Fp1: 3 times
#
# Top most common patterns:
# a1: 57 times
# d5: 57 times
# d4: 42 times
# d1: 36 times
# d2: 27 times
# d3: 6 times
#
# Top most common modulation intensities:
# A2: 33 times
# C1: 30 times
# A4: 24 times
# V1: 24 times
# C2: 24 times
# V3: 21 times
# A3: 21 times
# A1: 18 times
# V4: 15 times
# C3: 9 times
# V2: 6 times

# %% [markdown]
# ### Mutual information

# %%
filename = '/mnt/d/sharegit/MasterThesis_data/' + model_name + '/mutual_info_results.pkl'
loaded_results = load_from_pkl(filename)
print_best_most_common(loaded_results, feature_names)
# Out:
# Best Accuracy: 96.11% with 45 features
#
# Best Model Info:
# Model Name: RF
# Number of Features: 45
# Train Accuracy: 100.00%
# Test Accuracy: 96.11%
# Test Precision: 0.95
# Test Recall: 0.98
# Test F1 Score: 0.97
# Test ROC AUC: 0.99
#
# Top most common channels:
# Fp2: 18 times
# Fp1: 12 times
# P7: 12 times
# C4: 12 times
# O2: 12 times
# POz: 9 times
# CPz: 9 times
# Pz: 6 times
# O1: 6 times
# Cz: 6 times
# F7: 6 times
# F4: 6 times
# Fz: 6 times
# P4: 6 times
# T7: 3 times
# AFz: 3 times
# P8: 3 times
#
# Top most common patterns:
# d3: 33 times
# d1: 27 times
# d5: 27 times
# d2: 24 times
# a1: 15 times
# d4: 9 times
#
# Top most common modulation intensities:
# C1: 36 times
# A3: 21 times
# A1: 18 times
# V3: 15 times
# V2: 12 times
# V1: 9 times
# A4: 9 times
# C4: 6 times
# A2: 3 times
# C3: 3 times
# C2: 3 times

# %% [markdown]
# ### mRMR

# %%
filename = '/mnt/d/sharegit/MasterThesis_data/' + model_name + '/mrmr_results.pkl'
loaded_results = load_from_pkl(filename)
print_best_most_common(loaded_results, feature_names)
# Out:
# Best Accuracy: 97.04% with 75 features
#
# Best Model Info:
# Model Name: RF
# Number of Features: 75
# Train Accuracy: 100.00%
# Test Accuracy: 97.04%
# Test Precision: 0.96
# Test Recall: 0.99
# Test F1 Score: 0.97
# Test ROC AUC: 1.00
#
# Top most common channels:
# F4: 36 times
# C4: 33 times
# C3: 33 times
# Fp2: 30 times
# P3: 27 times
# Fp1: 24 times
# F3: 18 times
# P4: 12 times
# Pz: 6 times
# POz: 3 times
# T8: 3 times
#
# Top most common patterns:
# d3: 48 times
# d4: 42 times
# d5: 39 times
# d2: 39 times
# d1: 36 times
# a1: 21 times
#
# Top most common modulation intensities:
# C4: 36 times
# V1: 24 times
# V2: 24 times
# C1: 21 times
# A3: 21 times
# V4: 21 times
# C3: 21 times
# V3: 15 times
# A4: 15 times
# A2: 12 times
# A1: 12 times
# C2: 3 times
